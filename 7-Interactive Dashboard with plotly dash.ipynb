# %%
pip install -i https://pypi.tuna.tsinghua.edu.cn/simple jupyterlab
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: jupyterlab in d:\anaconda\lib\site-packages (3.5.3)
# Requirement already satisfied: jupyter-server<3,>=1.16.0 in d:\anaconda\lib\site-packages (from jupyterlab) (1.23.4)
# Requirement already satisfied: jupyter-core in d:\anaconda\lib\site-packages (from jupyterlab) (5.2.0)
# Requirement already satisfied: nbclassic in d:\anaconda\lib\site-packages (from jupyterlab) (0.5.2)
# Requirement already satisfied: packaging in d:\anaconda\lib\site-packages (from jupyterlab) (22.0)
# Requirement already satisfied: ipython in d:\anaconda\lib\site-packages (from jupyterlab) (8.10.0)
# Requirement already satisfied: tomli in d:\anaconda\lib\site-packages (from jupyterlab) (2.0.1)
# Requirement already satisfied: jinja2>=2.1 in d:\anaconda\lib\site-packages (from jupyterlab) (3.1.2)
# Requirement already satisfied: tornado>=6.1.0 in d:\anaconda\lib\site-packages (from jupyterlab) (6.1)
# Requirement already satisfied: jupyterlab-server~=2.10 in d:\anaconda\lib\site-packages (from jupyterlab) (2.19.0)
# Requirement already satisfied: notebook<7 in d:\anaconda\lib\site-packages (from jupyterlab) (6.5.2)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\anaconda\lib\site-packages (from jinja2>=2.1->jupyterlab) (2.1.1)
# Requirement already satisfied: traitlets>=5.1 in d:\anaconda\lib\site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (5.7.1)
# Requirement already satisfied: terminado>=0.8.3 in d:\anaconda\lib\site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (0.17.1)
# Requirement already satisfied: Send2Trash in d:\anaconda\lib\site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (1.8.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in d:\anaconda\lib\site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (7.3.4)
# Requirement already satisfied: pywinpty in d:\anaconda\lib\site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (2.0.10)
# Requirement already satisfied: anyio<4,>=3.1.0 in d:\anaconda\lib\site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (3.5.0)
# Requirement already satisfied: nbconvert>=6.4.4 in d:\anaconda\lib\site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (6.5.4)
# Requirement already satisfied: prometheus-client in d:\anaconda\lib\site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (0.14.1)
# Requirement already satisfied: argon2-cffi in d:\anaconda\lib\site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (21.3.0)
# Requirement already satisfied: pyzmq>=17 in d:\anaconda\lib\site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (23.2.0)
# Requirement already satisfied: nbformat>=5.2.0 in d:\anaconda\lib\site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (5.7.0)
# Requirement already satisfied: websocket-client in d:\anaconda\lib\site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (0.58.0)
# Requirement already satisfied: platformdirs>=2.5 in d:\anaconda\lib\site-packages (from jupyter-core->jupyterlab) (2.5.2)
# Requirement already satisfied: pywin32>=1.0 in d:\anaconda\lib\site-packages (from jupyter-core->jupyterlab) (305.1)
# Requirement already satisfied: requests>=2.28 in d:\anaconda\lib\site-packages (from jupyterlab-server~=2.10->jupyterlab) (2.28.1)
# Requirement already satisfied: babel>=2.10 in d:\anaconda\lib\site-packages (from jupyterlab-server~=2.10->jupyterlab) (2.11.0)
# Requirement already satisfied: jsonschema>=4.17.3 in d:\anaconda\lib\site-packages (from jupyterlab-server~=2.10->jupyterlab) (4.17.3)
# Requirement already satisfied: json5>=0.9.0 in d:\anaconda\lib\site-packages (from jupyterlab-server~=2.10->jupyterlab) (0.9.6)
# Requirement already satisfied: ipython-genutils in d:\anaconda\lib\site-packages (from notebook<7->jupyterlab) (0.2.0)
# Requirement already satisfied: nest-asyncio>=1.5 in d:\anaconda\lib\site-packages (from notebook<7->jupyterlab) (1.5.6)
# Requirement already satisfied: ipykernel in d:\anaconda\lib\site-packages (from notebook<7->jupyterlab) (6.19.2)
# Requirement already satisfied: notebook-shim>=0.1.0 in d:\anaconda\lib\site-packages (from nbclassic->jupyterlab) (0.2.2)
# Requirement already satisfied: stack-data in d:\anaconda\lib\site-packages (from ipython->jupyterlab) (0.2.0)
# Requirement already satisfied: matplotlib-inline in d:\anaconda\lib\site-packages (from ipython->jupyterlab) (0.1.6)
# Requirement already satisfied: colorama in d:\anaconda\lib\site-packages (from ipython->jupyterlab) (0.4.6)
# Requirement already satisfied: decorator in d:\anaconda\lib\site-packages (from ipython->jupyterlab) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in d:\anaconda\lib\site-packages (from ipython->jupyterlab) (0.18.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.30 in d:\anaconda\lib\site-packages (from ipython->jupyterlab) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in d:\anaconda\lib\site-packages (from ipython->jupyterlab) (2.11.2)
# Requirement already satisfied: backcall in d:\anaconda\lib\site-packages (from ipython->jupyterlab) (0.2.0)
# Requirement already satisfied: pickleshare in d:\anaconda\lib\site-packages (from ipython->jupyterlab) (0.7.5)
# Requirement already satisfied: idna>=2.8 in d:\anaconda\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.16.0->jupyterlab) (3.4)
# Requirement already satisfied: sniffio>=1.1 in d:\anaconda\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.16.0->jupyterlab) (1.2.0)
# Requirement already satisfied: pytz>=2015.7 in d:\anaconda\lib\site-packages (from babel>=2.10->jupyterlab-server~=2.10->jupyterlab) (2022.7)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in d:\anaconda\lib\site-packages (from jedi>=0.16->ipython->jupyterlab) (0.8.3)
# Requirement already satisfied: attrs>=17.4.0 in d:\anaconda\lib\site-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.10->jupyterlab) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in d:\anaconda\lib\site-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.10->jupyterlab) (0.18.0)
# Requirement already satisfied: entrypoints in d:\anaconda\lib\site-packages (from jupyter-client>=6.1.12->jupyter-server<3,>=1.16.0->jupyterlab) (0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\anaconda\lib\site-packages (from jupyter-client>=6.1.12->jupyter-server<3,>=1.16.0->jupyterlab) (2.8.2)
# Requirement already satisfied: tinycss2 in d:\anaconda\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (1.2.1)
# Requirement already satisfied: beautifulsoup4 in d:\anaconda\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (4.11.1)
# Requirement already satisfied: defusedxml in d:\anaconda\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (0.7.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in d:\anaconda\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in d:\anaconda\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (0.5.13)
# Requirement already satisfied: bleach in d:\anaconda\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (4.1.0)
# Requirement already satisfied: lxml in d:\anaconda\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (4.9.1)
# Requirement already satisfied: jupyterlab-pygments in d:\anaconda\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (0.1.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in d:\anaconda\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (1.5.0)
# Requirement already satisfied: fastjsonschema in d:\anaconda\lib\site-packages (from nbformat>=5.2.0->jupyter-server<3,>=1.16.0->jupyterlab) (2.16.2)
# Requirement already satisfied: wcwidth in d:\anaconda\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.30->ipython->jupyterlab) (0.2.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\anaconda\lib\site-packages (from requests>=2.28->jupyterlab-server~=2.10->jupyterlab) (1.26.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in d:\anaconda\lib\site-packages (from requests>=2.28->jupyterlab-server~=2.10->jupyterlab) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\lib\site-packages (from requests>=2.28->jupyterlab-server~=2.10->jupyterlab) (2022.12.7)
# Requirement already satisfied: argon2-cffi-bindings in d:\anaconda\lib\site-packages (from argon2-cffi->jupyter-server<3,>=1.16.0->jupyterlab) (21.2.0)
# Requirement already satisfied: debugpy>=1.0 in d:\anaconda\lib\site-packages (from ipykernel->notebook<7->jupyterlab) (1.5.1)
# Requirement already satisfied: psutil in d:\anaconda\lib\site-packages (from ipykernel->notebook<7->jupyterlab) (5.9.0)
# Requirement already satisfied: comm>=0.1.1 in d:\anaconda\lib\site-packages (from ipykernel->notebook<7->jupyterlab) (0.1.2)
# Requirement already satisfied: executing in d:\anaconda\lib\site-packages (from stack-data->ipython->jupyterlab) (0.8.3)
# Requirement already satisfied: pure-eval in d:\anaconda\lib\site-packages (from stack-data->ipython->jupyterlab) (0.2.2)
# Requirement already satisfied: asttokens in d:\anaconda\lib\site-packages (from stack-data->ipython->jupyterlab) (2.0.5)
# Requirement already satisfied: six in d:\anaconda\lib\site-packages (from websocket-client->jupyter-server<3,>=1.16.0->jupyterlab) (1.16.0)
# Requirement already satisfied: cffi>=1.0.1 in d:\anaconda\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=1.16.0->jupyterlab) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in d:\anaconda\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (2.3.2.post1)
# Requirement already satisfied: webencodings in d:\anaconda\lib\site-packages (from bleach->nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (0.5.1)
# Requirement already satisfied: pycparser in d:\anaconda\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=1.16.0->jupyterlab) (2.21)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -i https://pypi.tuna.tsinghua.edu.cn/simple dash==2.0.0
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Collecting dash==2.0.0
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/96/3f/f287d7a0084460e41abb636694a9dc13d030733687d944256fccdbac2ff8/dash-2.0.0-py3-none-any.whl (7.3 MB)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\razer\appdata\roaming\python\python310\site-packages (from dash==2.0.0) (2.0.0)
# Requirement already satisfied: flask-compress in c:\users\razer\appdata\roaming\python\python310\site-packages (from dash==2.0.0) (1.13)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\razer\appdata\roaming\python\python310\site-packages (from dash==2.0.0) (2.0.0)
# Requirement already satisfied: Flask>=1.0.4 in d:\anaconda\lib\site-packages (from dash==2.0.0) (2.2.2)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\razer\appdata\roaming\python\python310\site-packages (from dash==2.0.0) (5.0.0)
# Requirement already satisfied: plotly>=5.0.0 in d:\anaconda\lib\site-packages (from dash==2.0.0) (5.9.0)
# Requirement already satisfied: Werkzeug>=2.2.2 in c:\users\razer\appdata\roaming\python\python310\site-packages (from Flask>=1.0.4->dash==2.0.0) (2.2.2)
# Requirement already satisfied: Jinja2>=3.0 in d:\anaconda\lib\site-packages (from Flask>=1.0.4->dash==2.0.0) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in d:\anaconda\lib\site-packages (from Flask>=1.0.4->dash==2.0.0) (2.0.1)
# Requirement already satisfied: click>=8.0 in d:\anaconda\lib\site-packages (from Flask>=1.0.4->dash==2.0.0) (8.0.4)
# Requirement already satisfied: tenacity>=6.2.0 in d:\anaconda\lib\site-packages (from plotly>=5.0.0->dash==2.0.0) (8.0.1)
# Requirement already satisfied: brotli in c:\users\razer\appdata\roaming\python\python310\site-packages (from flask-compress->dash==2.0.0) (1.0.9)
# Requirement already satisfied: colorama in d:\anaconda\lib\site-packages (from click>=8.0->Flask>=1.0.4->dash==2.0.0) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\anaconda\lib\site-packages (from Jinja2>=3.0->Flask>=1.0.4->dash==2.0.0) (2.1.1)
# Installing collected packages: dash
#   Attempting uninstall: dash
#     Found existing installation: dash 2.13.0
#     Uninstalling dash-2.13.0:
#       Successfully uninstalled dash-2.13.0
# Successfully installed dash-2.0.0
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts dash-generate-components.exe, dash-update-components.exe and renderer.exe are installed in 'C:\Users\Razer\AppData\Roaming\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
pip install -i https://pypi.tuna.tsinghua.edu.cn/simple jupyter-dash
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: jupyter-dash in c:\users\razer\appdata\roaming\python\python310\site-packages (0.4.2)
# Requirement already satisfied: ansi2html in c:\users\razer\appdata\roaming\python\python310\site-packages (from jupyter-dash) (1.8.0)
# Requirement already satisfied: nest-asyncio in d:\anaconda\lib\site-packages (from jupyter-dash) (1.5.6)
# Requirement already satisfied: retrying in c:\users\razer\appdata\roaming\python\python310\site-packages (from jupyter-dash) (1.3.4)
# Requirement already satisfied: ipython in d:\anaconda\lib\site-packages (from jupyter-dash) (8.10.0)
# Requirement already satisfied: ipykernel in d:\anaconda\lib\site-packages (from jupyter-dash) (6.19.2)
# Requirement already satisfied: dash in c:\users\razer\appdata\roaming\python\python310\site-packages (from jupyter-dash) (2.0.0)
# Requirement already satisfied: flask in d:\anaconda\lib\site-packages (from jupyter-dash) (2.2.2)
# Requirement already satisfied: requests in d:\anaconda\lib\site-packages (from jupyter-dash) (2.28.1)
# Requirement already satisfied: plotly>=5.0.0 in d:\anaconda\lib\site-packages (from dash->jupyter-dash) (5.9.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\razer\appdata\roaming\python\python310\site-packages (from dash->jupyter-dash) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\razer\appdata\roaming\python\python310\site-packages (from dash->jupyter-dash) (5.0.0)
# Requirement already satisfied: flask-compress in c:\users\razer\appdata\roaming\python\python310\site-packages (from dash->jupyter-dash) (1.13)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\razer\appdata\roaming\python\python310\site-packages (from dash->jupyter-dash) (2.0.0)
# Requirement already satisfied: click>=8.0 in d:\anaconda\lib\site-packages (from flask->jupyter-dash) (8.0.4)
# Requirement already satisfied: itsdangerous>=2.0 in d:\anaconda\lib\site-packages (from flask->jupyter-dash) (2.0.1)
# Requirement already satisfied: Werkzeug>=2.2.2 in c:\users\razer\appdata\roaming\python\python310\site-packages (from flask->jupyter-dash) (2.2.2)
# Requirement already satisfied: Jinja2>=3.0 in d:\anaconda\lib\site-packages (from flask->jupyter-dash) (3.1.2)
# Requirement already satisfied: jupyter-client>=6.1.12 in d:\anaconda\lib\site-packages (from ipykernel->jupyter-dash) (7.3.4)
# Requirement already satisfied: pyzmq>=17 in d:\anaconda\lib\site-packages (from ipykernel->jupyter-dash) (23.2.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in d:\anaconda\lib\site-packages (from ipykernel->jupyter-dash) (0.1.6)
# Requirement already satisfied: tornado>=6.1 in d:\anaconda\lib\site-packages (from ipykernel->jupyter-dash) (6.1)
# Requirement already satisfied: traitlets>=5.4.0 in d:\anaconda\lib\site-packages (from ipykernel->jupyter-dash) (5.7.1)
# Requirement already satisfied: debugpy>=1.0 in d:\anaconda\lib\site-packages (from ipykernel->jupyter-dash) (1.5.1)
# Requirement already satisfied: packaging in d:\anaconda\lib\site-packages (from ipykernel->jupyter-dash) (22.0)
# Requirement already satisfied: psutil in d:\anaconda\lib\site-packages (from ipykernel->jupyter-dash) (5.9.0)
# Requirement already satisfied: comm>=0.1.1 in d:\anaconda\lib\site-packages (from ipykernel->jupyter-dash) (0.1.2)
# Requirement already satisfied: stack-data in d:\anaconda\lib\site-packages (from ipython->jupyter-dash) (0.2.0)
# Requirement already satisfied: pickleshare in d:\anaconda\lib\site-packages (from ipython->jupyter-dash) (0.7.5)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.30 in d:\anaconda\lib\site-packages (from ipython->jupyter-dash) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in d:\anaconda\lib\site-packages (from ipython->jupyter-dash) (2.11.2)
# Requirement already satisfied: backcall in d:\anaconda\lib\site-packages (from ipython->jupyter-dash) (0.2.0)
# Requirement already satisfied: decorator in d:\anaconda\lib\site-packages (from ipython->jupyter-dash) (5.1.1)
# Requirement already satisfied: colorama in d:\anaconda\lib\site-packages (from ipython->jupyter-dash) (0.4.6)
# Requirement already satisfied: jedi>=0.16 in d:\anaconda\lib\site-packages (from ipython->jupyter-dash) (0.18.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in d:\anaconda\lib\site-packages (from requests->jupyter-dash) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\lib\site-packages (from requests->jupyter-dash) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\anaconda\lib\site-packages (from requests->jupyter-dash) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda\lib\site-packages (from requests->jupyter-dash) (3.4)
# Requirement already satisfied: six>=1.7.0 in d:\anaconda\lib\site-packages (from retrying->jupyter-dash) (1.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in d:\anaconda\lib\site-packages (from jedi>=0.16->ipython->jupyter-dash) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\anaconda\lib\site-packages (from Jinja2>=3.0->flask->jupyter-dash) (2.1.1)
# Requirement already satisfied: entrypoints in d:\anaconda\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter-dash) (0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\anaconda\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter-dash) (2.8.2)
# Requirement already satisfied: jupyter-core>=4.9.2 in d:\anaconda\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter-dash) (5.2.0)
# Requirement already satisfied: tenacity>=6.2.0 in d:\anaconda\lib\site-packages (from plotly>=5.0.0->dash->jupyter-dash) (8.0.1)
# Requirement already satisfied: wcwidth in d:\anaconda\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.30->ipython->jupyter-dash) (0.2.5)
# Requirement already satisfied: brotli in c:\users\razer\appdata\roaming\python\python310\site-packages (from flask-compress->dash->jupyter-dash) (1.0.9)
# Requirement already satisfied: pure-eval in d:\anaconda\lib\site-packages (from stack-data->ipython->jupyter-dash) (0.2.2)
# Requirement already satisfied: executing in d:\anaconda\lib\site-packages (from stack-data->ipython->jupyter-dash) (0.8.3)
# Requirement already satisfied: asttokens in d:\anaconda\lib\site-packages (from stack-data->ipython->jupyter-dash) (2.0.5)
# Requirement already satisfied: pywin32>=1.0 in d:\anaconda\lib\site-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel->jupyter-dash) (305.1)
# Requirement already satisfied: platformdirs>=2.5 in d:\anaconda\lib\site-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel->jupyter-dash) (2.5.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -U dash
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: dash in c:\users\razer\appdata\roaming\python\python310\site-packages (2.0.0)
# Collecting dash
#   Using cached dash-2.13.0-py3-none-any.whl (10.4 MB)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\razer\appdata\roaming\python\python310\site-packages (from dash) (5.0.0)
# Requirement already satisfied: setuptools in d:\anaconda\lib\site-packages (from dash) (65.6.3)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\razer\appdata\roaming\python\python310\site-packages (from dash) (2.0.0)
# Requirement already satisfied: ansi2html in c:\users\razer\appdata\roaming\python\python310\site-packages (from dash) (1.8.0)
# Requirement already satisfied: nest-asyncio in d:\anaconda\lib\site-packages (from dash) (1.5.6)
# Requirement already satisfied: Werkzeug<2.3.0 in c:\users\razer\appdata\roaming\python\python310\site-packages (from dash) (2.2.2)
# Requirement already satisfied: typing-extensions>=4.1.1 in d:\anaconda\lib\site-packages (from dash) (4.4.0)
# Requirement already satisfied: requests in d:\anaconda\lib\site-packages (from dash) (2.28.1)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\razer\appdata\roaming\python\python310\site-packages (from dash) (2.0.0)
# Requirement already satisfied: retrying in c:\users\razer\appdata\roaming\python\python310\site-packages (from dash) (1.3.4)
# Requirement already satisfied: plotly>=5.0.0 in d:\anaconda\lib\site-packages (from dash) (5.9.0)
# Requirement already satisfied: Flask<2.3.0,>=1.0.4 in d:\anaconda\lib\site-packages (from dash) (2.2.2)
# Requirement already satisfied: Jinja2>=3.0 in d:\anaconda\lib\site-packages (from Flask<2.3.0,>=1.0.4->dash) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in d:\anaconda\lib\site-packages (from Flask<2.3.0,>=1.0.4->dash) (2.0.1)
# Requirement already satisfied: click>=8.0 in d:\anaconda\lib\site-packages (from Flask<2.3.0,>=1.0.4->dash) (8.0.4)
# Requirement already satisfied: tenacity>=6.2.0 in d:\anaconda\lib\site-packages (from plotly>=5.0.0->dash) (8.0.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in d:\anaconda\lib\site-packages (from Werkzeug<2.3.0->dash) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\anaconda\lib\site-packages (from requests->dash) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda\lib\site-packages (from requests->dash) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in d:\anaconda\lib\site-packages (from requests->dash) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\lib\site-packages (from requests->dash) (2022.12.7)
# Requirement already satisfied: six>=1.7.0 in d:\anaconda\lib\site-packages (from retrying->dash) (1.16.0)
# Requirement already satisfied: colorama in d:\anaconda\lib\site-packages (from click>=8.0->Flask<2.3.0,>=1.0.4->dash) (0.4.6)
# Installing collected packages: dash
#   Attempting uninstall: dash
#     Found existing installation: dash 2.0.0
#     Uninstalling dash-2.0.0:
#       Successfully uninstalled dash-2.0.0
# Successfully installed dash-2.13.0
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts dash-generate-components.exe, dash-update-components.exe and renderer.exe are installed in 'C:\Users\Razer\AppData\Roaming\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
pip install werkzeug==2.2.2
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: werkzeug==2.2.2 in c:\users\razer\appdata\roaming\python\python310\site-packages (2.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in d:\anaconda\lib\site-packages (from werkzeug==2.2.2) (2.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import dash
import dash_html_components as html
import dash_core_components as dcc
from dash.dependencies import Input, Output
import plotly.express as px



# Read the airline data into pandas dataframe
spacex_df=pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_dash.csv")
max_payload = spacex_df['Payload Mass (kg)'].max()
min_payload = spacex_df['Payload Mass (kg)'].min()

# Create a dash application
app = dash.Dash(__name__)

## Create an app layout

app.layout = html.Div(children=[html.H1('SpaceX Launch Records Dashboard',
                                        style={'textAlign': 'center', 'color': '#503D36',
                                               'font-size': 40}),
                                # TASK 1: Add a dropdown list to enable Launch Site selection
                                # The default select value is for ALL sites
                                dcc.Dropdown(
                                   id='site-dropdown',
                                   options=[
                                    {'label': 'All Sites', 'value': 'ALL'},
                                    {'label': 'CCAFS LC-40', 'value': 'CCAFS LC-40'},
                                    {'label': 'VAFB SLC-4E', 'value': 'VAFB SLC-4E'},
                                    {'label': 'KSC LC-39A', 'value': 'KSC LC-39A'},
                                    {'label': 'CCAFS SLC-40', 'value': 'CCAFS SLC-40'}],
                                    placeholder="Select a Launch Site here", value='ALL',
                                    searchable=True),

                                html.Br(),

                                # TASK 2: Add a pie chart to show the total successful launches count for all sites
                                # If a specific launch site was selected, show the Success vs. Failed counts for the site
                                html.Div(dcc.Graph(id='success-pie-chart')),
                                html.Br(),

                                html.P("Payload range (Kg):"),
                                # TASK 3: Add a slider to select payload range
                                #dcc.RangeSlider(id='payload-slider',...)
                                dcc.RangeSlider(id='payload-slider',
                                min=0,
                                max=10000,
                                step=1000,
                                value=[min_payload,max_payload],
                                marks={
                                0: '0 kg',
                                2500: '2500',
                                5000: '5000',
                                7500: '7500',
                                10000: '10000'
                                }),

                                # TASK 4: Add a scatter chart to show the correlation between payload and launch success
                                html.Div(dcc.Graph(id='success-payload-scatter-chart')),
                                ])

# TASK 2:
# Add a callback function for `site-dropdown` as input, `success-pie-chart` as output
@app.callback(
Output(component_id='success-pie-chart', component_property='figure'),
Input(component_id='site-dropdown', component_property='value')
)
def get_pie(value):
    filtered_df = spacex_df
    if value == 'ALL':
        fig = px.pie(spacex_df, values='class', names='Launch Site', title='Total Success Launches By Site')
        return fig

    else:
        filtered_df = spacex_df[spacex_df['Launch Site'] == value].groupby(['Launch Site', 'class']). \
        size().reset_index(name='class count')
        title = f"Total Success Launches for site {value}",
        fig = px.pie(filtered_df,values='class count', names='class', title=title)
        return fig

# TASK 4:
# Add a callback function for `site-dropdown` and `payload-slider` as inputs, `success-payload-scatter-chart` as output
@app.callback(
Output(component_id='success-payload-scatter-chart', component_property='figure'),
[Input(component_id='site-dropdown', component_property='value'),
Input(component_id='payload-slider', component_property='value')]
)

def get_scatter(value1,value2):
    filtered_df2_1=spacex_df[(spacex_df['Payload Mass (kg)'] > value2[0]) & (spacex_df['Payload Mass (kg)'] < value2[1])]

    if value1=='ALL':
        fig= px.scatter(filtered_df2_1,x="Payload Mass (kg)",y="class",color="Booster Version Category",\
        title="Correlation between Payload and Success for All sites")
        return fig
    else :
        filtered_df2_2=filtered_df2_1[filtered_df2_1['Launch Site']==value1]
        fig= px.scatter(filtered_df2_2,x="Payload Mass (kg)",y="class",color="Booster Version Category",\
        title=f"Correlation between Payload and Success for site {value1}")
        return fig

# Run the app
if __name__ == '__main__':
    app.run_server(port=2222)
# Out:
# C:\Users\Razer\AppData\Local\Temp\ipykernel_13044\2215892457.py:3: UserWarning:
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`
#   import dash_html_components as html
# C:\Users\Razer\AppData\Local\Temp\ipykernel_13044\2215892457.py:4: UserWarning:
# The dash_core_components package is deprecated. Please replace
# `import dash_core_components as dcc` with `from dash import dcc`
#   import dash_core_components as dcc
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:2222/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
